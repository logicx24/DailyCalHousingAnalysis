# %%
import json
with open('restaurants.json') as d:
    RAW = d.read()
RAW = '[' + RAW.replace('}{', '},{') + ']'
rest = json.loads(RAW)

# %%
#keys in each dic
list(rest[0].keys())
#keys in businesses
list(rest[0]['businesses'][0].keys())
# Out:
# [u'is_claimed',
#  u'rating',
#  u'mobile_url',
#  u'rating_img_url',
#  u'review_count',
#  u'name',
#  u'snippet_image_url',
#  u'rating_img_url_small',
#  u'url',
#  u'location',
#  u'menu_date_updated',
#  u'phone',
#  u'snippet_text',
#  u'image_url',
#  u'categories',
#  u'display_phone',
#  u'rating_img_url_large',
#  u'menu_provider',
#  u'id',
#  u'is_closed',
#  u'distance']

# %%
## Target format: [{'latitude': xxx, 'longtitude': xxx,
## 'businesses': [{'categories': xxx, 'name': xxx, 'rating': xxx, 'neighborhoods': xxx}, {}, {}...]}, {}, {} ...]

# import pdb; pdb.set_trace()
new = []
num_loc = len(rest)

for i in range(num_loc):
    one_loc = {}
    businesses = []
    one_loc['latitude'] = rest[i]['region']['center']['latitude']
    one_loc['longitude'] = rest[i]['region']['center']['longitude']
    # businesses
    num_bus = len(rest[i]['businesses'])
    for j in range(num_bus):    
        try:
            one_bus = rest[i]['businesses'][j]
        except:
            import pdb; pdb.set_trace()
        new_bus = {}
        new_bus['categories'] = one_bus['categories'][0][0]
        new_bus['name'] = one_bus['name']
        new_bus['rating'] = one_bus['rating']
        businesses.append(new_bus)
    one_loc['businesses'] = businesses
    new.append(one_loc)

# %%
json_str = json.dumps(new)
with open('clean_restaurant.json', 'w') as d:
    json.dump(json_str, d)

# %%
new[0]
# Out:
# {'businesses': [{'categories': u'Brazilian',
#    'name': u'Brazil Fresh Squeeze Cafe',
#    'rating': 4.5},
#   {'categories': u'Japanese', 'name': u'Simply Bowl', 'rating': 4.0},
#   {'categories': u'Cajun/Creole',
#    'name': u"Angeline's Louisiana Kitchen",
#    'rating': 4.0},
#   {'categories': u'Asian Fusion', 'name': u'Toss Noodle Bar', 'rating': 4.0},
#   {'categories': u'Pizza', 'name': u'Sliver Pizzeria', 'rating': 4.5},
#   {'categories': u'Vegan', 'name': u'Cinnaholic', 'rating': 4.5},
#   {'categories': u'Japanese', 'name': u'Sushinista', 'rating': 4.5},
#   {'categories': u'African',
#    'name': u'Suya African Caribbean Grill',
#    'rating': 4.0},
#   {'categories': u'Burgers', 'name': u'Eureka!', 'rating': 4.0},
#   {'categories': u'Thai', 'name': u'Imm Thai Street Food', 'rating': 4.0},
#   {'categories': u'Japanese', 'name': u'Sushi Secrets', 'rating': 4.0},
#   {'categories': u'Sushi Bars', 'name': u'Sumo Roll', 'rating': 4.5},
#   {'categories': u'Sandwiches', 'name': u'The Sandwich Spot', 'rating': 4.0},
#   {'categories': u'American (New)', 'name': u'Gather', 'rating': 4.0},
#   {'categories': u'Chinese', 'name': u'Great China', 'rating': 4.0},
#   {'categories': u'Japanese', 'name': u'Tamon Tea', 'rating': 4.5},
#   {'categories': u'Pubs', 'name': u'Jupiter', 'rating': 4.0},
#   {'categories': u'Latin American', 'name': u'Platano', 'rating': 4.0},
#   {'categories': u'Japanese', 'name': u'Ippuku', 'rating': 4.0},
#   {'categories': u'Italian', 'name': u'PIQ Bakery', 'rating': 4.0}],
#  'latitude': 37.8701173693928,
#  'longitude': -122.267956974363}

# %%
# Average rating & #Cafes & #Pubs
analysis = []
for i in range(len(new)):
    loc = {}
    loc['latitude'] = new[i]['latitude']
    loc['longitude'] = new[i]['longitude']
    total = 0
    num_bus = len(new[i]['businesses'])
    for j in range(num_bus):
        total += new[i]['businesses'][j]['rating']
    loc['avg_rating'] = float(total) / float(num_bus)
    
    cafe = 0
    pub = 0
    num_bus = len(new[i]['businesses'])
    for j in range(num_bus):
        if ('Coffee' in new[i]['businesses'][j]['categories']) or ('Cafe' in new[i]['businesses'][j]['name']):
            cafe += 1
        if ('Pubs' in new[i]['businesses'][j]['categories']) or ('Bar' in new[i]['businesses'][j]['name']):
            pub += 1
    loc['#cafes'] = cafe
    loc['#pubs'] = pub
    
    analysis.append(loc)

# %%
analysis
# Out:
# [{'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.15,
#   'latitude': 37.8701173693928,
#   'longitude': -122.267956974363},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.87145812335905,
#   'longitude': -122.2715429226865},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.87145812335905,
#   'longitude': -122.2715094186895},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.87145812335905,
#   'longitude': -122.2715094186895},
#  {'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.125,
#   'latitude': 37.87015754946255,
#   'longitude': -122.267956974363},
#  {'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.125,
#   'latitude': 37.87015754946255,
#   'longitude': -122.267956974363},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.872112358929655,
#   'longitude': -122.27186085},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 4.075,
#   'latitude': 37.871147223359046,
#   'longitude': -122.2688142996665},
#  {'#cafes': 2,
#   '#pubs': 1,
#   'avg_rating': 4.1,
#   'latitude': 37.87015754946255,
#   'longitude': -122.2686708},
#  {'#cafes': 2,
#   '#pubs': 1,
#   'avg_rating': 4.1,
#   'latitude': 37.87015754946255,
#   'longitude': -122.2686708},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 4.05,
#   'latitude': 37.87145812335905,
#   'longitude': -122.26980597848001},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 4.05,
#   'latitude': 37.87145812335905,
#   'longitude': -122.26980597848001},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 4.025,
#   'latitude': 37.87145812335905,
#   'longitude': -122.26911302848},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 4.1,
#   'latitude': 37.87145812335905,
#   'longitude': -122.2686708},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 4.0,
#   'latitude': 37.87148791497615,
#   'longitude': -122.27019625},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.95,
#   'latitude': 37.87245112335905,
#   'longitude': -122.271647528838},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 3.975,
#   'latitude': 37.87148791497615,
#   'longitude': -122.27020734999999},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 4.0,
#   'latitude': 37.8716437,
#   'longitude': -122.26980597848001},
#  {'#cafes': 6,
#   '#pubs': 0,
#   'avg_rating': 3.8,
#   'latitude': 37.871335166997056,
#   'longitude': -122.27352619999999},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 4.0,
#   'latitude': 37.8716437,
#   'longitude': -122.26980597848001},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.87368846706695,
#   'longitude': -122.27061885},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.825,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26849595},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.9,
#   'latitude': 37.866864199999995,
#   'longitude': -122.26538615000001},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.86560688943035,
#   'longitude': -122.26319455000001},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26811267400649},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.2680830983695},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.2680830983695},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.2680830983695},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.2680830983695},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.2680830983695},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 2,
#   '#pubs': 1,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26388775000001},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.95,
#   'latitude': 37.86560688943035,
#   'longitude': -122.2626381},
#  {'#cafes': 0,
#   '#pubs': 0,
#   'avg_rating': 3.975,
#   'latitude': 37.865493201399204,
#   'longitude': -122.2620921001415},
#  {'#cafes': 0,
#   '#pubs': 0,
#   'avg_rating': 4.0,
#   'latitude': 37.8651455,
#   'longitude': -122.2598691},
#  {'#cafes': 0,
#   '#pubs': 0,
#   'avg_rating': 4.0,
#   'latitude': 37.8651455,
#   'longitude': -122.2598011},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.725,
#   'latitude': 37.82173701487195,
#   'longitude': -122.33927700976551},
#  {'#cafes': 4,
#   '#pubs': 2,
#   'avg_rating': 3.7,
#   'latitude': 37.8671923925687,
#   'longitude': -122.269990789151},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.85,
#   'latitude': 37.86708196706695,
#   'longitude': -122.26851995000001},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.2680830983695},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 2,
#   '#pubs': 1,
#   'avg_rating': 3.9,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26393759999999},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.95,
#   'latitude': 37.86560688943035,
#   'longitude': -122.2626381},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.975,
#   'latitude': 37.

#  {'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.05,
#   'latitude': 37.867417092111296,
#   'longitude': -122.26667805},
#  {'#cafes': 8,
#   '#pubs': 1,
#   'avg_rating': 3.425,
#   'latitude': 37.86626290674695,
#   'longitude': -122.25365099999999},
#  {'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.075,
#   'latitude': 37.8671375,
#   'longitude': -122.265630228838},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.865493201399204,
#   'longitude': -122.26247425},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 4.075,
#   'latitude': 37.87446596706695,
#   'longitude': -122.2677207},
#  {'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.1,
#   'latitude': 37.87015754946255,
#   'longitude': -122.267956974363},
#  {'#cafes': 2,
#   '#pubs': 2,
#   'avg_rating': 4.15,
#   'latitude': 37.8693312761035,
#   'longitude': -122.267956974363},
#  {'#cafes': 0,
#   '#pubs': 0,
#   'avg_rating': 4.025,
#   'latitude': 37.86386835,
#   'longitude': -122.2584159},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 4.025,
#   'latitude': 37.87512821706695,
#   'longitude': -122.26670999999999},
#  {'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.075,
#   'latitude': 37.867172,
#   'longitude': -122.26749775},
#  {'#cafes': 1,
#   '#pubs': 2,
#   'avg_rating': 4.075,
#   'latitude': 37.867172,
#   'longitude': -122.267542},
#  {'#cafes': 6,
#   '#pubs': 0,
#   'avg_rating': 3.725,
#   'latitude': 37.87482288690075,
#   'longitude': -122.258140593767},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 4.425,
#   'latitude': 37.93995365,
#   'longitude': -122.22651515000001},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 3.925,
#   'latitude': 37.8668909925687,
#   'longitude': -122.26538615000001},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.95,
#   'latitude': 37.863530850000004,
#   'longitude': -122.26230471744},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.675,
#   'latitude': 37.87497443690075,
#   'longitude': -122.26024921942951},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.975,
#   'latitude': 37.86258345,
#   'longitude': -122.25659915},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 4.0,
#   'latitude': 37.875413550000005,
#   'longitude': -122.2681206},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.8633253,
#   'longitude': -122.26247425},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.675,
#   'latitude': 37.8756063882505,
#   'longitude': -122.26312796322651},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 4.075,
#   'latitude': 37.875127967066945,
#   'longitude': -122.2686708},
#  {'#cafes': 2,
#   '#pubs': 1,
#   'avg_rating': 3.875,
#   'latitude': 37.864008649708495,
#   'longitude': -122.266426174363},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.86289065,
#   'longitude': -122.25886399999999},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.725,
#   'latitude': 37.87652242138845,
#   'longitude': -122.258395118963},
#  {'#cafes': 4,
#   '#pubs': 1,
#   'avg_rating': 3.775,
#   'latitude': 37.8633937,
#   'longitude': -122.26547020000001},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.86289065,
#   'longitude': -122.2597374},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.86289065,
#   'longitude': -122.25868765},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.675,
#   'latitude': 37.8758929882505,
#   'longitude': -122.26312796322651},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.55,
#   'latitude': 37.875448000000006,
#   'longitude': -122.26371115},
#  {'#cafes': 3,
#   '#pubs': 2,
#   'avg_rating': 4.05,
#   'latitude': 37.87145812335905,
#   'longitude': -122.26911302848},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.7,
#   'latitude': 37.8629455,
#   'longitude': -122.2661556},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.86209255,
#   'longitude': -122.25619624999999},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.86268604999999,
#   'longitude': -122.25951900000001},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 4.025,
#   'latitude': 37.8771923865782,
#   'longitude': -122.26787139999999},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.975,
#   'latitude': 37.8757664,
#   'longitude': -122.26911302848},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 4.025,
#   'latitude': 37.8749886684895,
#   'longitude': -122.26911302848},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.65,
#   'latitude': 37.8629455,
#   'longitude': -122.26669025},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.825,
#   'latitude': 37.86187505,
#   'longitude': -122.25549575},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.425,
#   'latitude': 37.81081315,
#   'longitude': -122.3694929},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 4.025,
#   'latitude': 37.87446596706695,
#   'longitude': -122.26911302848},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 4.0,
#   'latitude': 37.8769185604747,
#   'longitude': -122.26838532848001},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.75,
#   'latitude': 37.861740850000004,
#   'longitude': -122.26635195},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.975,
#   'latitude': 37.765397171957005,
#   'longitude': -122.1226286276475},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.86104215,
#   'longitude': -122.25619624999999},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.775,
#   'latitude': 37.8611242,
#   'longitude': -122.25564284999999},
#  {'#cafes': 6,
#   '#pubs': 0,
#   'avg_rating': 3.7,
#   'latitude': 37.86195145,
#   'longitude': -122.2532132},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.675,
#   'latitude': 37.73070545,
#   'longitude': -122.07239820000001},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 4.53125,
#   'latitude': 37.653756371957,
#   'longitude': -122.101641943701},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.675,
#   'latitude': 37.87725942138845,
#   'longitude': -122.2607657027115},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.75,
#   'latitude': 37.861740850000004,
#   'longitude': -122.26633015},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.862306149999995,
#   'longitude': -122.2589294},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.862306149999995,
#   'longitude': -122.2589294},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.862306149999995,
#   'longitude': -122.2589294},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.95,
#   'latitude': 37.860858449999995,
#   'longitude': -122.25619624999999},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.775,
#   'latitude': 37.86106145,
#   'longitude': -122.25558054999999},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8611242,
#   'longitude': -122.25536475},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 4.0,
#   'latitude': 37.8774975604747,
#   'longitude': -122.2684504},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.862306149999995,
#   'longitude': -122.26006185},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.825,
#   'latitude': 37.8606689761569,
#   'longitude': -122.2597874},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.86104215,
#   'longitude': -122.25619624999999},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.825,
#   'latitude': 37.86106145,
#   'longitude': -122.25549575},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8591260635655,
#   'longitude': -122.2532405},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8592151,
#   'longitude': -122.2532328},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.75,
#   'latitude': 37.861740850000004,
#   'longitude': -122.26716730000001},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.8,
#   'latitude': 37.860956849999994,
#   'longitude': -122.266186},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8592151,
#   'longitude': -122.2532328},
#  {'#cafes': 6,
#   '#pubs': 0,
#   'avg_rating': 3.7,
#   'latitude': 37.86195145,
#   'longitude': -122.2532132},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.825,
#   'latitude': 37.8612,
#   'longitude': -122.26662115},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.725,
#   'latitude': 37.8607503,
#   'longitude': -122.2663074997385},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.75,
#   'latitude': 37.860400126156904,
#   'longitude': -122.25973205},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.95,
#   'latitude': 37.860858449999995,
#   'longitude': -122.25619624999999},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.86104215,
#   'longitude': -122.25584275},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8591260635655,
#   'longitude': -122.2532295},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.86026665,
#   'longitude': -122.2628566193185},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.86094695,
#   'longitude': -122.25584275},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.8603551,
#   'longitude': -122.26342365},
#  {'#cafes': 1,
#   '#pubs': 0,
#   'avg_rating': 3.775,
#   'latitude': 37.8600594,
#   'longitude': -122.26225415},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.860784100000004,
#   'longitude': -122.25619624999999},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.925,
#   'latitude': 37.860858449999995,
#   'longitude': -122.25595325},
#  {'#cafes': 4,
#   '#pubs': 1,
#   'avg_rating': 3.825,
#   'latitude': 37.8779191,
#   'longitude': -122.26692665},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.775,
#   'latitude': 37.8601928761569,
#   'longitude': -122.25952155},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.860717050000005,
#   'longitude': -122.25595325},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.875,
#   'latitude': 37.86077145,
#   'longitude': -122.25544805000001},
#  {'#cafes': 5,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8592151,
#   'longitude': -122.2527417},
#  {'#cafes': 0,
#   '#pubs': 0,
#   'avg_rating': 4.533333333333333,
#   'latitude': 37.653756371957,
#   'longitude': -122.101641943701},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 3.9,
#   'latitude': 37.8776256,
#   'longitude': -122.26747},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.872112358929655,
#   'longitude': -122.27219185},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.8,
#   'latitude': 37.8594607,
#   'longitude': -122.2590037},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.8,
#   'latitude': 37.8594607,
#   'longitude': -122.2590037},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8591260635655,
#   'longitude': -122.25320555},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8591260635655,
#   'longitude': -122.25285305},
#  {'#cafes': 3,
#   '#pubs': 1,
#   'avg_rating': 3.575,
#   'latitude': 37.866462299999995,
#   'longitude': -122.2691532},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.729567450000005,
#   'longitude': -122.07799385},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.95,
#   'latitude': 37.8594607,
#   'longitude': -122.2565461},
#  {'#cafes': 2,
#   '#pubs': 0,
#   'avg_rating': 3.9,
#   'latitude': 37.86047085,
#   'longitude': -122.25595325},
#  {'#cafes': 3,
#   '#pubs': 0,
#   'avg_rating': 3.775,
#   'latitude': 37.86047085,
#   'longitude': -122.25574524999999},
#  {'#cafes': 4,
#   '#pubs': 0,
#   'avg_rating': 3.85,
#   'latitude': 37.8591260635655,
#   'longitude': -122.25320555},
#  ...]
