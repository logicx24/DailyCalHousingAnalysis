# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool
import pandas as pd
from bokeh.io import output_notebook
import numpy as np
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0697a3cd-da2d-4bc5-9d1a-8c779f31ee5e">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv("final_no_outlier")

latitude = df['latitude'].tolist()
longitude = df['longitude'].tolist()
price = df['price per room'].tolist()
r = [0.0003] * len(price)
address = df['address'].tolist()
distance = df['edge_distance'].tolist()
sqft = df['sqft per room'].tolist()
food = df['avg_rating'].tolist()
cafes = df['#cafes'].tolist()
pubs = df['#pubs'].tolist()

# %%
farNorth = [[37.88745, 37.87796, 37.88057, 37.88303, 37.89135], 
            [-122.30581, -122.30323, -122.28302, -122.26349, -122.26456]]
farWest = [[37.87796, 37.88057, 37.87221, 37.86614, 37.85313, 37.85059], 
           [-122.30323, -122.28302, -122.28182, -122.28092, -122.27903, -122.29482]]
farSouth = [[37.85059, 37.83886, 37.84679, 37.85843, 37.85519, 37.85313], 
            [-122.29482, -122.29165, -122.24255, -122.24541, -122.26588, -122.27903]]
north = [[37.88057,37.88303, 37.87553, 37.87418, 37.87221],
        [-122.28302, -122.26349, -122.25688, -122.26628, -122.28182]]
west = [[37.87221, 37.87418, 37.86756, 37.86614],
       [-122.28182, -122.26628, -122.26641, -122.28092]]
south = [[37.86756, 37.86977, 37.85843, 37.85519],
        [-122.26641, -122.24847, -122.24541, -122.26588]]
southwest = [[37.86756, 37.86614, 37.85313, 37.85519],
            [-122.26641, -122.28092, -122.27903, -122.26588]]

color = ["#FFA500", "#AFEEEE", "#BDB76B", "#FA8072", "#8B008B", "grey", "brown"]

y = [farNorth[0], farWest[0], farSouth[0], north[0], west[0], south[0], southwest[0]]
x = [farNorth[1], farWest[1], farSouth[1], north[1], west[1], south[1], southwest[1]]

p = figure(title = "Test")
source = ColumnDataSource(data=dict(
    xs = x,
    ys = y,
    color = color,
))
p.patches('xs', 'ys', source = source, line_color = "black", 
          fill_color = 'color', line_width = 0.5, fill_alpha = 0.4)
show(p)
# Out:
#     <div class="plotdiv" id="26927498-c693-404b-a120-c8e5f28df866"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("26927498-c693-404b-a120-c8e5f28df866");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '26927498-c693-404b-a120-c8e5f28df866' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b3aa0945-f26c-4760-85e5-c38b760e1df4":{"roots":{"references":[{"attributes":{"callback":null},"id":"1cf7ea46-2245-4796-b9ea-3901aee2c76b","type":"DataRange1d"},{"attributes":{},"id":"5088a872-38bc-4954-af49-a01042fa1764","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"bca9cccf-02ee-48a7-841e-81479df54364","subtype":"Figure","type":"Plot"}},"id":"40b76bee-22de-4220-bb78-a03b15cb7e44","type":"ResizeTool"},{"attributes":{},"id":"04aa169c-3227-4856-9188-bf0793ac61cc","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"b4b7f3d5-ba44-423c-9323-d82f22cc26e2","subtype":"Figure","type":"Plot"},"ticker":{"id":"1fd9ae58-a15d-47d2-b364-0ca7ea6ce984","type":"BasicTicker"}},"id":"42cff0d1-4d46-4613-8272-d7952f539847","type":"Grid"},{"attributes":{"plot":{"id":"89ca2423-2dd6-488c-b2b1-d6d9298efb47","subtype":"Figure","type":"Plot"}},"id":"fc22368d-d55e-420b-a1fd-9c3cd29fa019","type":"ResetTool"},{"attributes":{"plot":{"id":"897691a5-db01-48ac-a404-b2472b7c7e6e","subtype":"Figure","type":"Plot"}},"id":"1fd927a2-c679-4b9d-a6f7-e4d55574ea76","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"4af9f6db-7d59-4228-a675-152e17788973","subtype":"Figure","type":"Plot"}},"id":"7a39b704-3ef6-43bf-9522-64bf83bb31ff","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a76c401e-c665-4720-b001-19c16bfe56c8","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"f5e4e5d6-eba0-4f53-919b-4eb7034a63f7","subtype":"Figure","type":"Plot"}},"id":"e89cd9f8-75bd-4db3-ba00-6fec0c8ff311","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["color","ys","xs"],"data":{"color":["#FFA500","#AFEEEE","#BDB76B","#FA8072","orange","grey","brown"],"xs":[[-122.30581,-122.30323,-122.28302,-122.26349,-122.26456],[-122.30323,-122.28302,-122.28182,-122.28092,-122.27903,-122.29482],[-122.29482,-122.29165,-122.24255,-122.24541,-122.26588,-122.27903],[-122.28302,-122.26349,-122.25688,-122.26628,-122.28182],[-122.28182,-122.26628,-122.26641,-122.28092],[-122.26641,-122.24847,-122.24541,-122.26588],[-122.26641,-122.28092,-122.27903,-122.26588]],"ys":[[37.88745,37.87796,37.88057,37.88303,37.89135],[37.87796,37.88057,37.87221,37.86614,37.85313,37.85059],[37.85059,37.83886,37.84679,37.85843,37.85519,37.85313],[37.88057,37.88303,37.87553,37.87418,37.87221],[37.87221,37.87418,37.86756,37.86614],[37.86756,37.86977,37.85843,37.85519],[37.86756,37.86614,37.85313,37.85519]]}},"id":"66627744-65fb-4706-9a55-fdb9bb14132e","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8d87f10b-3a13-4fdf-8479-df230550c7fc","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"a012d76d-b1cd-4785-8f16-ae0a724059d1","type":"BasicTickFormatter"},"plot":{"id":"153778c7-8a33-497d-97e9-465f9f8beea0","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb4f9de9-11c3-48ad-af9d-1016a4d06169","type":"BasicTicker"}},"id":"d10843b0-cbda-46ea-9ee7-3fad16b6d469","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["color","ys","xs"],"data":{"color":["#FFA500","#AFEEEE","#BDB76B","#FA8072","#8B008B","grey","brown"],"xs":[[-122.30581,-122.30323,-122.28302,-122.26349,-122.26456],[-122.30323,-122.28302,-122.28182,-122.28092,-122.27903,-122.29482],[-122.29482,-122.29165,-122.24255,-122.24541,-122.26588,-122.27903],[-122.28302,-122.26349,-122.25688,-122.26628,-122.28182],[-122.28182,-122.26628,-122.26641,-122.28092],[-122.26641,-122.24847,-122.24541,-122.26588],[ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %%
map_options = GMapOptions(lat=37.87, lng=-122.27, map_type="roadmap", zoom=14)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, title="Austin"
)
plot.add_glyph(p)
show(plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-fd16f6c88dc7> in <module>()
#       4     x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, title="Austin"
#       5 )
# ----> 6 plot.add_glyph(p)
#       7 show(plot)
#
# /Users/yikaluo/anaconda/lib/python3.5/site-packages/bokeh/models/plots.py in add_glyph(self, source_or_glyph, glyph, **kw)
#     234
#     235         if not isinstance(glyph, Glyph):
# --> 236             raise ValueError("'glyph' argument to add_glyph() must be Glyph subclass")
#     237
#     238         g = GlyphRenderer(data_source=source, glyph=glyph, **kw)
#
# ValueError: 'glyph' argument to add_glyph() must be Glyph subclass
